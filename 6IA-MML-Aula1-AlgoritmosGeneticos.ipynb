# %% [markdown]
# # 6IA - Modelos de Machine Learning
# ## Aula 1

# %%
geneSet = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!."
target = "duan nunes alves da silva"

# %%
import random

def generate_parent(lenght):
  genes = []
  
  while len(genes)<lenght:
    sampleSize = min(lenght - len(genes), len(geneSet))
    
    genes.extend(random.sample(geneSet, sampleSize))
    
  return ''.join(genes)

# %%
def get_fitness(guess):
  return sum(1 for expected, actual in zip(target, guess) if expected == actual)

# %%
import datetime

def mutate(parent):
  index = random.randrange(0, len(parent))
  childGenes = list(parent)
  newGene, alternate = random.sample(geneSet, 2)
  childGenes[index] = alternate if newGene == childGenes[index] else newGene
  
  return ''.join(childGenes)

# %%
def display(guess):
  timeDiff = datetime.datetime.now() - startTime
  fitness = get_fitness(guess)
  print("{0}\t{1}\t{2}".format(guess, fitness, str(timeDiff)))

# %%
random.seed(42)

startTime = datetime.datetime.now()
bestParent = generate_parent(len(target))
bestFitness = get_fitness(bestParent)

display(bestParent)

i = 0

while True:
  i=i+1
  child = mutate(bestParent)
  childFitness = get_fitness(child)
  
  if bestFitness >= childFitness:
    continue
    
  display(child)
  
  if childFitness >= len(bestParent):
    break
    
  bestFitness = childFitness
  bestParent = child
  
print(i)
# Out:
# NgaUqonhfQHeKAbZSmVFMlzJE	1	0:00:00.000142
# NgaUqonhfQHeKAbZ mVFMlzJE	2	0:00:00.002157
# dgaUqonhfQHeKAbZ mVFMlzJE	3	0:00:00.002654
# dgaUqonhfQHeKAbZ mVFslzJE	4	0:00:00.003585
# dgaUqonnfQHeKAbZ mVFslzJE	5	0:00:00.004585
# dgaUqonnfQHeKAbZ mVFslzJa	6	0:00:00.006237
# dgaUqonnfQHeKAbZ maFslzJa	7	0:00:00.006614
# dgaUqonnfQ eKAbZ maFslzJa	8	0:00:00.006822
# dgaUqonnfQ eKAbZ daFslzJa	9	0:00:00.007618
# dgaUqonnfQ eKAeZ daFslzJa	10	0:00:00.008073
# dgaU onnfQ eKAeZ daFslzJa	11	0:00:00.009743
# dgaU onnfQ eKAeZ daFsizJa	12	0:00:00.011308
# dgaU onnfs eKAeZ daFsizJa	13	0:00:00.012797
# dgaU ounfs eKAeZ daFsizJa	14	0:00:00.013522
# dgaU ounfs aKAeZ daFsizJa	15	0:00:00.017858
# dgaU ounes aKAeZ daFsizJa	16	0:00:00.019399
# dgaU nunes aKAeZ daFsizJa	17	0:00:00.020567
# dgaU nunes alAeZ daFsizJa	18	0:00:00.028367
# dgaU nunes alveZ daFsizJa	19	0:00:00.028805
# dgaU nunes alveZ da sizJa	20	0:00:00.029078
# dgaU nunes alves da sizJa	21	0:00:00.029487
# duaU nunes alves da sizJa	22	0:00:00.034821
# duan nunes alves da sizJa	23	0:00:00.038574
# duan nunes alves da silJa	24	0:00:00.042298
# duan nunes alves da silva	25	0:00:00.048282
# 4394
